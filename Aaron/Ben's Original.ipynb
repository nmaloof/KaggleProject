# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from scipy.stats import norm
# %matplotlib inline
import math

# %%
train = pd.read_csv('train.csv')

# %%
test = pd.read_csv('test.csv')

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1460.000000  1460.000000    1460.000000  1460.000000
# mean       ...          94.244521    46.660274      21.954110     3.409589
# std        ...         125.338794    66.256028      61.119149    29.317331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 38 columns]

# %%
test.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704
# std       1.113740    30.390071     21.130467   177.625900   455.268042
# min       1.000000  1879.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1953.000000   1963.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1992.000000     0.000000   350.500000
# 75%       6.000000  2001.000000   2004.000000   164.000000   753.500000
# max       9.000000  2010.000000   2010.000000  1290.000000  4010.000000
#
#           ...        GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# count     ...       1458.000000  1459.000000  1459.000000    1459.000000
# mean      ...        472.768861    93.174777    48.313914      24.243317
# std       ...        217.048611   127.744882    68.883364      67.227765
# min       ...          0.000000     0.000000     0.000000       0.000000
# 25%       ...        318.000000     0.000000     0.000000       0.000000
# 50%       ...        480.000000     0.000000    28.000000       0.000000
# 75%       ...        576.000000   168.000000    72.000000       0.000000
# max       ...       1488.000000  1424.000000   742.000000    1012.000000
#
#          3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold  \
# count  1459.000000  1459.000000  1459.000000   1459.000000  1459.000000
# mean      1.794380    17.064428     1.744345     58.167923     6.104181
# std      20.207842    56.609763    30.491646    630.806978     2.722432
# min       0.000000     0.000000     0.000000      0.000000     1.000000
# 25%       0.000000     0.000000     0.000000      0.000000     4.000000
# 50%       0.000000     0.000000     0.000000      0.000000     6.000000
# 75%       0.000000     0.000000     0.000000      0.000000     8.000000
# max     360.000000   576.000000   800.000000  17000.000000    12.000000
#
#             YrSold
# count  1459.000000
# mean   2007.769705
# std       1.301740
# min    2006.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2010.000000
#
# [8 rows x 37 columns]

# %%
train_ID = train['Id']
test_ID = test['Id']

train.drop("Id", axis = 1, inplace = True)
test.drop("Id", axis = 1, inplace = True)

# %%
sns.jointplot(x="GrLivArea", y="SalePrice", data=train)

# %% [markdown]
# From the descriptive thing:
#     "There are 5 observations that an instructor may wish to remove from the data set before giving it to students (a plot of SALE PRICE versus GR LIV AREA will indicate them quickly). Three of them are true outliers (Partial Sales that likely don’t represent actual market values) and two of them are simply unusual sales (very large houses priced relatively appropriately)."

# %%
# outliers
train = train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)].index)

# %%
#replotting
sns.jointplot(x ="GrLivArea", y="SalePrice", data=train)

# %%
sns.distplot(train['SalePrice'], fit=norm);
fig = plt.figure()
res = stats.probplot(train['SalePrice'], plot=plt)

# %% [markdown]
# trying out log1p to see if i can undo it for the results

# %%
train["SalePrice"] = np.log1p(train["SalePrice"])

# %%
#from sklearn import preprocessing
#from scipy.stats import boxcox

# %%
# correcting the skew and kurtosis on our SalePrice variable using BoxCox
#train['SalePrice'] = preprocessing.scale(boxcox(train['SalePrice']+1)[0])

# %%
sns.distplot(train['SalePrice'], fit=norm);
fig = plt.figure()
res = stats.probplot(train['SalePrice'], plot=plt)

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
y_train = train.SalePrice.values
data = pd.concat((train, test)).reset_index(drop=True)
data.drop(['SalePrice'], axis=1, inplace=True)
print("data size is : {}".format(data.shape))
# Out:
# data size is : (2917, 79)

# %% [markdown]
# # Dealing with Missingness

# %%
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending=False)
missing = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing.head(35)
# Out:
#               Total    Percent
# PoolQC         2908  99.691464
# MiscFeature    2812  96.400411
# Alley          2719  93.212204
# Fence          2346  80.425094
# FireplaceQu    1420  48.680151
# LotFrontage     486  16.660953
# GarageFinish    159   5.450806
# GarageQual      159   5.450806
# GarageYrBlt     159   5.450806
# GarageCond      159   5.450806
# GarageType      157   5.382242
# BsmtCond         82   2.811107
# BsmtExposure     82   2.811107
# BsmtQual         81   2.776826
# BsmtFinType2     80   2.742544
# BsmtFinType1     79   2.708262
# MasVnrType       24   0.822763
# MasVnrArea       23   0.788481
# MSZoning          4   0.137127
# BsmtHalfBath      2   0.068564
# Utilities         2   0.068564
# Functional        2   0.068564
# BsmtFullBath      2   0.068564
# Electrical        1   0.034282
# Exterior2nd       1   0.034282
# KitchenQual       1   0.034282
# GarageCars        1   0.034282
# Exterior1st       1   0.034282
# GarageArea        1   0.034282
# TotalBsmtSF       1   0.034282
# BsmtUnfSF         1   0.034282
# BsmtFinSF2        1   0.034282
# BsmtFinSF1        1   0.034282
# SaleType          1   0.034282
# Condition2        0   0.000000

# %% [markdown]
# Missing Features:
#     Alley: data desc says na means "no alley access"
#     BsmtQual, BsmtCond, BsmntExposure, BsmtFinType1, BsmtFinType2: data desc says NA means "no basement"
#     FireplaceQU: desc says NA means "No Fireplace"
#     GarageType, GarageFinish,GaraGarageQual, GarageCond: desc says NA means "No Garage"
#     PoolQC: desc says NA means "No Pool"
#     Fence: desc says NA means "No Fence"
#     MiscFeature: desc says NA means "None"

# %%
data["Alley"] = data["Alley"].fillna("None")
data["BsmtQual"] = data["BsmtQual"].fillna("None")
data["BsmtCond"] = data["BsmtCond"].fillna("None")
data["BsmtExposure"] = data["BsmtExposure"].fillna("None")
data["BsmtFinType1"] = data["BsmtFinType1"].fillna("None")
data["BsmtFinType2"] = data["BsmtFinType2"].fillna("None")

# %%
data["FireplaceQu"] = data["FireplaceQu"].fillna("None")
data["GarageType"] = data["GarageType"].fillna("None")
data["GarageFinish"] = data["GarageFinish"].fillna("None")
data["GarageQual"] = data["GarageQual"].fillna("None")
data["GarageCond"] = data["GarageCond"].fillna("None")
data["PoolQC"] = data["PoolQC"].fillna("None")
data["Fence"] = data["Fence"].fillna("None")
data["MiscFeature"] = data["MiscFeature"].fillna("None")

# %%
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending=False)
missing = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing.head(8)
# Out:
#               Total    Percent
# LotFrontage     486  16.660953
# GarageYrBlt     159   5.450806
# MasVnrType       24   0.822763
# MasVnrArea       23   0.788481
# MSZoning          4   0.137127
# Functional        2   0.068564
# Utilities         2   0.068564
# BsmtFullBath      2   0.068564

# %%
sns.barplot(data=data,x='Neighborhood',y='LotFrontage', estimator=np.median)
plt.xticks(rotation=90)
plt.show()
plt.gcf().clear()

# %% [markdown]
# neighborhood seems a pretty good at determining lot frontage- using the mean neighborhood lot frontage to impute the missing lot frontages

# %%
data["LotFrontage"] = data.groupby("Neighborhood")["LotFrontage"].transform(
    lambda x: x.fillna(x.median()))

# %%
data["GarageYrBlt"] = data["GarageYrBlt"].fillna(0)

# %% [markdown]
# most likely no basement so setting these basement measurements to zero

# %%
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    data[col] = data[col].fillna(0)

# %% [markdown]
# Probably no masonry veneer for these houses so setting to 0 or none

# %%
data["MasVnrType"] = data["MasVnrType"].fillna("None")
data["MasVnrArea"] = data["MasVnrArea"].fillna(0)

# %% [markdown]
# filling the 4 missing zoning's with residential- the most common seen zoning type

# %%
data['MSZoning'] = data['MSZoning'].fillna(data['MSZoning'].mode()[0])

# %% [markdown]
# trying dropping utilities to see if this improves accuracy

# %%
data = data.drop(['Utilities'], axis=1)

# %% [markdown]
# filling missing functional with most common type (typ)

# %%
data['Functional'] = data['Functional'].fillna("Typ")

# %% [markdown]
# removing missing garage cars and area

# %%
data['GarageCars'] = data['GarageCars'].fillna(0)
data['GarageArea'] = data['GarageArea'].fillna(0)

# %% [markdown]
# filling the remaining missing values by the most commonly seen value

# %%
data['Exterior1st'] = data['Exterior1st'].fillna(data['Exterior1st'].mode()[0])
data['Exterior2nd'] = data['Exterior2nd'].fillna(data['Exterior2nd'].mode()[0])
data['KitchenQual'] = data['KitchenQual'].fillna(data['KitchenQual'].mode()[0])
data['SaleType'] = data['SaleType'].fillna(data['SaleType'].mode()[0])
data['Electrical'] = data['Electrical'].fillna(data['Electrical'].mode()[0])

# %%
data['Functional'] = data['Functional'].fillna(data['Functional'].mode()[0])

# %%
data_corr = data.corr()

# %%
data_corr
# Out:
#                              1stFlrSF  2ndFlrSF  3SsnPorch     Alley  \
# 1stFlrSF                     1.000000 -0.390599   0.044821  0.077319
# 2ndFlrSF                    -0.390599  1.000000  -0.030489 -0.064954
# 3SsnPorch                    0.044821 -0.030489   1.000000  0.020906
# Alley                        0.077319 -0.064954   0.020906  1.000000
# BedroomAbvGr                 0.115936  0.429047  -0.051682 -0.051316
# BsmtCond                     0.053076 -0.037911  -0.003522  0.078803
# BsmtExposure                -0.222677  0.167703   0.004356 -0.053060
# BsmtFinSF1                   0.228758 -0.199685   0.058226  0.101417
# BsmtFinSF2                   0.066724 -0.124884  -0.009616  0.006598
# BsmtFinType1                -0.089254  0.177583  -0.054339 -0.093566
# BsmtFinType2                -0.027163  0.099981  -0.001421 -0.007731
# BsmtFullBath                 0.255169 -0.212278   0.033471  0.081359
# BsmtHalfBath                 0.013053 -0.062644   0.043087 -0.012977
# BsmtQual                    -0.339583 -0.035947  -0.019144 -0.111110
# BsmtUnfSF                    0.163643  0.077210  -0.006016 -0.029016
# CentralAir                   0.171602 -0.022616   0.030154  0.143957
# EnclosedPorch               -0.114724  0.072907  -0.031297 -0.194317
# ExterCond                    0.072914 -0.037276  -0.015934  0.090702
# ExterQual                   -0.357124 -0.014893  -0.057805 -0.099979
# Fence                        0.067000  0.026668  -0.007641  0.026043
# FireplaceQu                 -0.139364  0.085446  -0.008789  0.004680
# Fireplaces                   0.398853  0.117341   0.031479  0.053318
# FullBath                     0.365983  0.303415   0.018191  0.105508
# Functional                  -0.078324  0.005145  -0.021017  0.003917
# GarageArea                   0.318678  0.024938   0.019673  0.107380
# GarageCars                   0.416272  0.075022   0.021325  0.112978
# GarageCond                   0.165994 -0.017083   0.007907  0.152669
# GarageFinish                -0.227049 -0.060962  -0.005434 -0.086595
# GarageQual                   0.174377 -0.051061  -0.004645  0.158271
# GarageYrBlt                  0.152607  0.021539   0.014033  0.090946
# ...                               ...       ...        ...       ...
# SaleType_OverallCond_Con6   -0.018290  0.001959  -0.002943 -0.055010
# SaleType_OverallCond_ConLD1 -0.023790  0.015251  -0.002081  0.001974
# SaleType_OverallCond_ConLD2 -0.005116 -0.015919  -0.002081  0.001974
# SaleType_OverallCond_ConLD3 -0.034002 -0.022516  -0.002943 -0.055010
# SaleType_OverallCond_ConLD4  0.001633 -0.000904  -0.004163  0.003951
# SaleType_OverallCond_ConLD5 -0.006535 -0.010221  -0.007221  0.036874
# SaleType_OverallCond_ConLD6 -0.005382 -0.022516  -0.002943  0.002793
# SaleType_OverallCond_ConLD7 -0.015285 -0.014583  -0.003605  0.003421
# SaleType_OverallCond_ConLD8 -0.021158 -0.015919  -0.002081  0.001974
# SaleType_OverallCond_ConLI5  0.015193  0.005707  -0.005101  0.004841
# SaleType_OverallCond_ConLI6 -0.007188 -0.022516  -0.002943  0.002793
# SaleType_OverallCond_ConLI8 -0.026770  0.018055  -0.002081 -0.079757
# SaleType_OverallCond_ConLw3 -0.018286 -0.015919  -0.002081  0.001974
# SaleType_OverallCond_ConLw5 -0.021602 -0.009669  -0.003605  0.003421
# SaleType_OverallCond_ConLw6 -0.043559  0.039224  -0.004163  0.003951
# SaleType_OverallCond_New2    0.030887 -0.015919  -0.002081  0.001974
# SaleType_OverallCond_New5    0.187959 -0.015988   0.040374  0.081105
# SaleType_OverallCond_New6    0.023636 -0.023186  -0.005101  0.004841
# SaleType_OverallCond_Oth3    0.015397 -0.015919  -0.002081  0.001974
# SaleType_OverallCond_Oth5   -0.015079 -0.027582  -0.003605  0.003421
# SaleType_OverallCond_Oth6    0.003422 -0.027582  -0.003605  0.003421
# SaleType_OverallCond_WD1     0.000747  0.016305  -0.004656 -0.032159
# SaleType_OverallCond_WD2    -0.009719 -0.004155  -0.005892 -0.023340
# SaleType_OverallCond_WD3    -0.027628 -0.022640  -0.013248 -0.052479
# SaleType_OverallCond_WD4    -0.023281  0.004097  -0.003996 -0.010188
# SaleType_OverallCond_WD5     0.107150  0.038264  -0.038146  0.112284
# SaleType_OverallCond_WD6    -0.077956 -0.051462  -0.019274 -0.017840
# SaleType_OverallCond_WD7    -0.121123  0.011812   0.040701 -0.053276
# SaleType_OverallCond_WD8    -0.099435  0.043830   0.001736 -0.119635
# SaleType_OverallCond_WD9    -0.028926  0.062818   0.060905 -0.070238
#
#                              BedroomAbvGr  BsmtCond  BsmtExposure  BsmtFinSF1  \
# 1stFlrSF                         0.115936  0.053076     -0.222677    0.228758
# 2ndFlrSF                         0.429047 -0.037911      0.167703   -0.199685
# 3SsnPorch                       -0.051682 -0.003522      0.004356    0.058226
# Alley                           -0.051316  0.078803     -0.053060    0.101417
# BedroomAbvGr                     1.000000  0.005860      0.127220   -0.103086
# BsmtCond                         0.005860  1.000000     -0.083823    0.104938
# BsmtExposure                     0.127220 -0.083823      1.000000   -0.236222
# BsmtFinSF1                      -0.103086  0.104938     -0.236222    1.000000
# BsmtFinSF2                      -0.024457  0.004099     -0.054224    0.147091
# BsmtFinType1                     0.073019 -0.081879      0.144970   -0.699776
# BsmtFinType2                     0.049043  0.033744      0.034772   -0.075580
# BsmtFullBath                    -0.174948  0.073804     -0.259938    0.618272
# BsmtHalfBath                     0.021484 -0.002367     -0.055621    0.113628
# BsmtQual                         0.085568 -0.015072      0.274952   -0.093894
# BsmtUnfSF                        0.178562  0.128321      0.045254   -0.345353
# CentralAir                       0.048853  0.194074     -0.114604    0.190847
# EnclosedPorch                    0.015713 -0.111882      0.126860   -0.126294
# ExterCond                       -0.017298  0.181627     -0.078268    0.020839
# ExterQual                        0.067240 -0.016041      0.195582   -0.066792
# Fence                           -0.022249 -0.014220     -0.071746   -0.060421
# FireplaceQu                      0.052616  0.010935      0.092077   -0.002847
# Fireplaces                       0.082656  0.040905     -0.141184    0.194807
# FullBath                         0.362332  0.029933     -0.070417   -0.047398
# Functional                       0.000456  0.084767     -0.079976    0.042184
# GarageArea                       0.024345  0.116197     -0.134925    0.171013
# GarageCars                       0.071491  0.115182     -0.199464    0.138389
# GarageCond                       0.015193  0.171431     -0.084608    0.163934
# GarageFinish                    -0.005205 -0.069746      0.199966   -0.084844
# GarageQual                       0.036163  0.149287     -0.104253    0.196233
# GarageYrBlt                     -0.016113  0.097494     -0.048063    0.135286
# ...                                   ...       ...           ...         ...
# SaleType_OverallCond_Con6        0.006584  0.008355      0.014860    0.014894
# SaleType_OverallCond_ConLD1     -0.018830 -0.077732      0.010506   -0.025533
# SaleType_OverallCond_ConLD2     -0.018830 -0.077732      0.010506   -0.025533
# SaleType_OverallCond_ConLD3     -0.048858 -0.050797      0.014860   -0.036115
# SaleType_OverallCond_ConLD4     -0.029903 -0.044410      0.025647   -0.009120
# SaleType_OverallCond_ConLD5     -0.004544  0.003863     -0.003199   -0.007052
# SaleType_OverallCond_ConLD6      0.003360 -0.011987      0.021398   -0.036115
# SaleType_OverallCond_ConLD7      0.005432 -0.006378      0.023542   -0.023126
# SaleType_OverallCond_ConLD8     -0.050254  0.005907      0.010506   -0.025533
# SaleType_OverallCond_ConLI5      0.039039  0.014481      0.010111    0.022141
# SaleType_OverallCond_ConLI6      0.006584  0.008355      0.014860   -0.012223
# SaleType_OverallCond_ConLI8      0.004655 -0.077732     -0.000964   -0.025533
# SaleType_OverallCond_ConLw3     -0.050254 -0.077732      0.010506   -0.025533
# SaleType_OverallCond_ConLw5     -0.026280  0.010235      0.018203    0.001727
# SaleType_OverallCond_ConLw6      0.009314 -0.030021     -0.010224   -0.005602
# SaleType_OverallCond_New2       -0.050254  0.005907     -0.040484    0.022162
# SaleType_OverallCond_New5       -0.034451  0.009887     -0.149003   -0.084706
# SaleType_OverallCond_New6       -0.007780  0.014481     -0.015913   -0.027549
# SaleType_OverallCond_Oth3        0.023581  0.005907     -0.016313    0.022124
# SaleType_OverallCond_Oth5        0.008065  0.010235      0.011578   -0.005148
# SaleType_OverallCond_Oth6        0.022622  0.010235      0.018203   -0.016461
# SaleType_OverallCond_WD1         0.026856 -0.067387      0.011506   -0.032150
# SaleType_OverallCond_WD2         0.001641 -0.086817      0.033023   -0.072305
# SaleType_OverallCond_WD3         0.001049 -0.100950      0.061774   -0.057213
# SaleType_OverallCond_WD4         0.041777 -0.070625      0.056645   -0.057231
# SaleType_OverallCond_WD5         0.012149  0.092783     -0.102480    0.072683
# SaleType_OverallCond_WD6        -0.001010  0.025735      0.044347    0.078021
# SaleType_OverallCond_WD7         0.001018 -0.019544      0.086120   -0.005147
# SaleType_OverallCond_WD8        -0.004912 -0.028673      0.041681   -0.038534
# SaleType_OverallCond_WD9         0.013966 -0.028109      0.030971   -0.021386
#
#                              BsmtFinSF2  BsmtFinType1  \
# 1stFlrSF                       0.066724     -0.089254
# 2ndFlrSF                      -0.124884      0.177583
# 3SsnPorch                     -0.009616     -0.054339
# Alley                          0.006598     -0.093566
# BedroomAbvGr                  -0.024457      0.073019
# BsmtCond                       0.004099     -0.081879
# BsmtExposure                  -0.054224      0.144970
# BsmtFinSF1                     0.147091     -0.699776
# BsmtFinSF2                     1.000000     -0.175745
# BsmtFinType1                  -0.175745      1.000000
# BsmtFinType2                  -0.778568      0.071497
# BsmtFullBath                   0.165571     -0.412300
# BsmtHalfBath                   0.130039     -0.118958
# BsmtQual                       0.124442     -0.036793
# BsmtUnfSF                     -0.309332      0.283178
# CentralAir                     0.058855     -0.145628
# EnclosedPorch                  0.027366      0.105063
# ExterCond                     -0.055081     -0.007596
# ExterQual                      0.083567     -0.043180
# Fence                         -0.109758      0.064458
# FireplaceQu                    0.024466     -0.030910
# Fireplaces                     0.043908     -0.116431
# FullBath                      -0.101136      0.078133
# Functional                    -0.081512     -0.028786
# GarageArea                     0.039866     -0.090702
# GarageCars                    -0.022845     -0.056780
# GarageCond                     0.042033     -0.121539
# GarageFinish                   0.057330      0.022419
# GarageQual                     0.071105     -0.150231
# GarageYrBlt                    0.058601     -0.085031
# ...                                 ...           ...
# SaleType_OverallCond_Con6      0.033043     -0.022769
# SaleType_OverallCond_ConLD1   -0.006633      0.020289
# SaleType_OverallCond_ConLD2   -0.006633      0.020289
# SaleType_OverallCond_ConLD3   -0.009381      0.028698
# SaleType_OverallCond_ConLD4   -0.013272      0.014738
# SaleType_OverallCond_ConLD5   -0.007998     -0.014802
# SaleType_OverallCond_ConLD6   -0.009381      0.021305
# SaleType_OverallCond_ConLD7   -0.011492     -0.001937
# SaleType_OverallCond_ConLD8   -0.006633      0.020289
# SaleType_OverallCond_ConLI5   -0.016260      0.003088
# SaleType_OverallCond_ConLI6   -0.009381      0.016603
# SaleType_OverallCond_ConLI8   -0.006633      0.020289
# SaleType_OverallCond_ConLw3   -0.006633      0.020289
# SaleType_OverallCond_ConLw5   -0.011492     -0.000502
# SaleType_OverallCond_ConLw6    0.074392      0.010807
# SaleType_OverallCond_New2     -0.006633     -0.005061
# SaleType_OverallCond_New5     -0.104787      0.108247
# SaleType_OverallCond_New6     -0.016260      0.029025
# SaleType_OverallCond_Oth3     -0.006633     -0.005061
# SaleType_OverallCond_Oth5     -0.011492      0.011335
# SaleType_OverallCond_Oth6     -0.011492      0.014139
# SaleType_OverallCond_WD1      -0.014841      0.026942
# SaleType_OverallCond_WD2      -0.018782      0.053754
# SaleType_OverallCond_WD3      -0.016370      0.046853
# SaleType_OverallCond_WD4       0.044840      0.039937
# SaleType_OverallCond_WD5      -0.048325      0.016804
# SaleType_OverallCond_WD6       0.060342     -0.082966
# SaleType_OverallCond_WD7       0.050409     -0.085273
# SaleType_OverallCond_WD8       0.014734     -0.003483
# SaleType_OverallCond_WD9       0.006785     -0.001281
#
#                                        ...             \
# 1stFlrSF                               ...
# 2ndFlrSF                               ...
# 3SsnPorch                              ...
# Alley                                  ...
# BedroomAbvGr                           ...
# BsmtCond                               ...
# BsmtExposure                           ...
# BsmtFinSF1                             ...
# BsmtFinSF2                             ...
# BsmtFinType1                           ...
# BsmtFinType2                           ...
# BsmtFullBath                           ...
# BsmtHalfBath                           ...
# BsmtQual                               ...
# BsmtUnfSF                              ...
# CentralAir                             ...
# EnclosedPorch                          ...
# ExterCond                              ...
# ExterQual                              ...
# Fence                                  ...
# FireplaceQu                            ...
# Fireplaces                             ...
# FullBath                               ...
# Functional                             ...
# GarageArea                             ...
# GarageCars                             ...
# GarageCond                             ...
# GarageFinish                           ...
# GarageQual                             ...
# GarageYrBlt                            ...
# ...                                    ...
# SaleType_OverallCond_Con6              ...
# SaleType_OverallCond_ConLD1            ...
# SaleType_OverallCond_ConLD2            ...
# SaleType_OverallCond_ConLD3            ...
# SaleType_OverallCond_ConLD4            ...
# SaleType_OverallCond_ConLD5            ...
# SaleType_OverallCond_ConLD6            ...
# SaleType_OverallCond_ConLD7            ...
# SaleType_OverallCond_ConLD8            ...
# SaleType_OverallCond_ConLI5            ...
# SaleType_OverallCond_ConLI6            ...
# SaleType_OverallCond_ConLI8            ...
# SaleType_OverallCond_ConLw3            ...
# SaleType_OverallCond_ConLw5            ...
# SaleType_OverallCond_ConLw6            ...
# SaleType_OverallCond_New2              ...
# SaleType_OverallCond_New5              ...
# SaleType_OverallCond_New6              ...
# SaleType_OverallCond_Oth3              ...
# SaleType_OverallCond_Oth5              ...
# SaleType_OverallCond_Oth6              ...
# SaleType_OverallCond_WD1               ...
# SaleType_OverallCond_WD2               ...
# SaleType_OverallCond_WD3               ...
# SaleType_OverallCond_WD4               ...
# SaleType_OverallCond_WD5               ...
# SaleType_OverallCond_WD6               ...
# SaleType_OverallCond_WD7               ...
# SaleType_OverallCond_WD8               ...
# SaleType_OverallCond_WD9               ...
#
#                              SaleType_OverallCond_Oth6  \
# 1stFlrSF                                      0.003422
# 2ndFlrSF                                     -0.027582
# 3SsnPorch                                    -0.003605
# Alley                                         0.003421
# BedroomAbvGr                                  0.022622
# BsmtCond                                      0.010235
# BsmtExposure                                  0.018203
# BsmtFinSF1                                   -0.016461
# BsmtFinSF2                                   -0.011492
# BsmtFinType1                                  0.014139
# BsmtFinType2                                  0.010226
# BsmtFullBath                                  0.007654
# BsmtHalfBath                                 -0.008068
# BsmtQual                                     -0.016180
# BsmtUnfSF                                     0.005244
# CentralAir                                    0.008612
# EnclosedPorch                                 0.037815
# ExterCond                                    -0.013378
# ExterQual                                     0.018352
# Fence                                        -0.001581
# FireplaceQu                                   0.001961
# Fireplaces                                   -0.031426
# FullBath                                     -0.013293
# Functional                                    0.007654
# GarageArea                                   -0.045905
# GarageCars                                   -0.036356
# GarageCond                                   -0.013108
# GarageFinish                                  0.012915
# GarageQual                                   -0.008260
# GarageYrBlt                                  -0.039840
# ...                                                ...
# SaleType_OverallCond_Con6                    -0.000840
# SaleType_OverallCond_ConLD1                  -0.000594
# SaleType_OverallCond_ConLD2                  -0.000594
# SaleType_OverallCond_ConLD3                  -0.000840
# SaleType_OverallCond_ConLD4                  -0.001189
# SaleType_OverallCond_ConLD5                  -0.002062
# SaleType_OverallCond_ConLD6                  -0.000840
# SaleType_OverallCond_ConLD7                  -0.001030
# SaleType_OverallCond_ConLD8                  -0.000594
# SaleType_OverallCond_ConLI5                  -0.001457
# SaleType_OverallCond_ConLI6                  -0.000840
# SaleType_OverallCond_ConLI8                  -0.000594
# SaleType_OverallCond_ConLw3                  -0.000594
# SaleType_OverallCond_ConLw5                  -0.001030
# SaleType_OverallCond_ConLw6                  -0.001189
# SaleType_OverallCond_New2                    -0.000594
# SaleType_OverallCond_New5                    -0.009387
# SaleType_OverallCond_New6                    -0.001457
# SaleType_OverallCond_Oth3                    -0.000594
# SaleType_OverallCond_Oth5                    -0.001030
# SaleType_OverallCond_Oth6                     1.000000
# SaleType_OverallCond_WD1                     -0.001330
# SaleType_OverallCond_WD2                     -0.001683
# SaleType_OverallCond_WD3                     -0.003783
# SaleType_OverallCond_WD4                     -0.005855
# SaleType_OverallCond_WD5                     -0.029434
# SaleType_OverallCond_WD6                     -0.014382
# SaleType_OverallCond_WD7                     -0.012361
# SaleType_OverallCond_WD8                     -0.007231
# SaleType_OverallCond_WD9                     -0.003783
#
#                              SaleType_OverallCond_WD1  \
# 1stFlrSF                                     0.000747
# 2ndFlrSF                                     0.016305
# 3SsnPorch                                   -0.004656
# Alley                                       -0.032159
# BedroomAbvGr                                 0.026856
# BsmtCond                                    -0.067387
# BsmtExposure                                 0.011506
# BsmtFinSF1                                  -0.032150
# BsmtFinSF2                                  -0.014841
# BsmtFinType1                                 0.026942
# BsmtFinType2                                 0.013206
# BsmtFullBath                                -0.018210
# BsmtHalfBath                                -0.010420
# BsmtQual                                     0.001873
# BsmtUnfSF                                    0.016459
# CentralAir                                  -0.088187
# EnclosedPorch                                0.009075
# ExterCond                                   -0.018716
# ExterQual                                    0.002537
# Fence                                        0.005911
# FireplaceQu                                  0.002532
# Fireplaces                                  -0.040585
# FullBath                                    -0.020846
# Functional                                  -0.177868
# GarageArea                                  -0.130500
# GarageCars                                  -0.103323
# GarageCond                                  -0.100596
# GarageFinish                                -0.008640
# GarageQual                                  -0.043695
# GarageYrBlt                                 -0.136386
# ...                                               ...
# SaleType_OverallCond_Con6                   -0.001085
# SaleType_OverallCond_ConLD1                 -0.000767
# SaleType_OverallCond_ConLD2                 -0.000767
# SaleType_OverallCond_ConLD3                 -0.001085
# SaleType_OverallCond_ConLD4                 -0.001535
# SaleType_OverallCond_ConLD5                 -0.002663
# SaleType_OverallCond_ConLD6                 -0.001085
# SaleType_OverallCond_ConLD7                 -0.001330
# SaleType_OverallCond_ConLD8                 -0.000767
# SaleType_OverallCond_ConLI5                 -0.001881
# SaleType_OverallCond_ConLI6                 -0.001085
# SaleType_OverallCond_ConLI8                 -0.000767
# SaleType_OverallCond_ConLw3                 -0.000767
# SaleType_OverallCond_ConLw5                 -0.001330
# SaleType_OverallCond_ConLw6                 -0.001535
# SaleType_OverallCond_New2                   -0.000767
# SaleType_OverallCond_New5                   -0.012123
# SaleType_OverallCond_New6                   -0.001881
# SaleType_OverallCond_Oth3                   -0.000767
# SaleType_OverallCond_Oth5                   -0.001330
# SaleType_OverallCond_Oth6                   -0.001330
# SaleType_OverallCond_WD1                     1.000000
# SaleType_OverallCond_WD2                    -0.002173
# SaleType_OverallCond_WD3                    -0.004886
# SaleType_OverallCond_WD4                    -0.007561
# SaleType_OverallCond_WD5                    -0.038013
# SaleType_OverallCond_WD6                    -0.018573
# SaleType_OverallCond_WD7                    -0.015964
# SaleType_OverallCond_WD8                    -0.009339
# SaleType_OverallCond_WD9                    -0.004886
#
#                              SaleType_OverallCond_WD2  \
# 1stFlrSF                                    -0.009719
# 2ndFlrSF                                    -0.004155
# 3SsnPorch                                   -0.005892
# Alley                                       -0.023340
# BedroomAbvGr                                 0.001641
# BsmtCond                                    -0.086817
# BsmtExposure                                 0.033023
# BsmtFinSF1                                  -0.072305
# BsmtFinSF2                                  -0.018782
# BsmtFinType1                                 0.053754
# BsmtFinType2                                 0.009608
# BsmtFullBath                                -0.017893
# BsmtHalfBath                                -0.013187
# BsmtQual                                     0.015116
# BsmtUnfSF                                    0.019273
# CentralAir                                  -0.064476
# EnclosedPorch                                0.028586
# ExterCond                                   -0.048027
# ExterQual                                    0.029995
# Fence                                        0.006151
# FireplaceQu                                 -0.015232
# Fireplaces                                  -0.010070
# FullBath                                    -0.013494
# Functional                                  -0.085457
# GarageArea                                  -0.061847
# GarageCars                                  -0.046432
# GarageCond                                  -0.136235
# GarageFinish                                 0.018247
# GarageQual                                  -0.080006
# GarageYrBlt                                 -0.074630
# ...                                               ...
# SaleType_OverallCond_Con6                   -0.001374
# SaleType_OverallCond_ConLD1                 -0.000971
# SaleType_OverallCond_ConLD2                 -0.000971
# SaleType_OverallCond_ConLD3                 -0.001374
# SaleType_OverallCond_ConLD4                 -0.001943
# SaleType_OverallCond_ConLD5                 -0.003370
# SaleType_OverallCond_ConLD6                 -0.001374
# SaleType_OverallCond_ConLD7                 -0.001683
# SaleType_OverallCond_ConLD8                 -0.000971
# SaleType_OverallCond_ConLI5                 -0.002381
# SaleType_OverallCond_ConLI6                 -0.001374
# SaleType_OverallCond_ConLI8                 -0.000971
# SaleType_OverallCond_ConLw3                 -0.000971
# SaleType_OverallCond_ConLw5                 -0.001683
# SaleType_OverallCond_ConLw6                 -0.001943
# SaleType_OverallCond_New2                   -0.000971
# SaleType_OverallCond_New5                   -0.015343
# SaleType_OverallCond_New6                   -0.002381
# SaleType_OverallCond_Oth3                   -0.000971
# SaleType_OverallCond_Oth5                   -0.001683
# SaleType_OverallCond_Oth6                   -0.001683
# SaleType_OverallCond_WD1                    -0.002173
# SaleType_OverallCond_WD2                     1.000000
# SaleType_OverallCond_WD3                    -0.006183
# SaleType_OverallCond_WD4                    -0.009569
# SaleType_OverallCond_WD5                    -0.048107
# SaleType_OverallCond_WD6                    -0.023505
# SaleType_OverallCond_WD7                    -0.020204
# SaleType_OverallCond_WD8                    -0.011819
# SaleType_OverallCond_WD9                    -0.006183
#
#                              SaleType_OverallCond_WD3  \
# 1stFlrSF                                    -0.027628
# 2ndFlrSF                                    -0.022640
# 3SsnPorch                                   -0.013248
# Alley                                       -0.052479
# BedroomAbvGr                                 0.001049
# BsmtCond                                    -0.100950
# BsmtExposure                                 0.061774
# BsmtFinSF1                                  -0.057213
# BsmtFinSF2                                  -0.016370
# BsmtFinType1                                 0.046853
# BsmtFinType2                                -0.002620
# BsmtFullBath                                -0.019175
# BsmtHalfBath                                 0.006887
# BsmtQual                                     0.044704
# BsmtUnfSF                                   -0.026436
# CentralAir                                  -0.180295
# EnclosedPorch                                0.054638
# ExterCond                                   -0.103016
# ExterQual                                    0.030892
# Fence                                        0.009824
# FireplaceQu                                  0.033080
# Fireplaces                                  -0.029615
# FullBath                                    -0.044301
# Functional                                  -0.074177
# GarageArea                                  -0.121310
# GarageCars                                  -0.106992
# GarageCond                                  -0.083629
# GarageFinish                                 0.035187
# GarageQual                                  -0.059798
# GarageYrBlt                                 -0.115320
# ...                                               ...
# SaleType_OverallCond_Con6                   -0.003089
# SaleType_OverallCond_ConLD1                 -0.002184
# SaleType_OverallCond_ConLD2                 -0.002184
# SaleType_OverallCond_ConLD3                 -0.003089
# SaleType_OverallCond_ConLD4                 -0.004369
# SaleType_OverallCond_ConLD5                 -0.007578
# SaleType_OverallCond_ConLD6                 -0.003089
# SaleType_OverallCond_ConLD7                 -0.003783
# SaleType_OverallCond_ConLD8                 -0.002184
# SaleType_OverallCond_ConLI5                 -0.005353
# SaleType_OverallCond_ConLI6                 -0.003089
# SaleType_OverallCond_ConLI8                 -0.002184
# SaleType_OverallCond_ConLw3                 -0.002184
# SaleType_OverallCond_ConLw5                 -0.003783
# SaleType_OverallCond_ConLw6                 -0.004369
# SaleType_OverallCond_New2                   -0.002184
# SaleType_OverallCond_New5                   -0.034498
# SaleType_OverallCond_New6                   -0.005353
# SaleType_OverallCond_Oth3                   -0.002184
# SaleType_OverallCond_Oth5                   -0.003783
# SaleType_OverallCond_Oth6                   -0.003783
# SaleType_OverallCond_WD1                    -0.004886
# SaleType_OverallCond_WD2                    -0.006183
# SaleType_OverallCond_WD3                     1.000000
# SaleType_OverallCond_WD4                    -0.021516
# SaleType_OverallCond_WD5                    -0.108168
# SaleType_OverallCond_WD6                    -0.052851
# SaleType_OverallCond_WD7                    -0.045427
# SaleType_OverallCond_WD8                    -0.026574
# SaleType_OverallCond_WD9                    -0.013903
#
#                              SaleType_OverallCond_WD4  \
# 1stFlrSF                                    -0.023281
# 2ndFlrSF                                     0.004097
# 3SsnPorch                                   -0.003996
# Alley                                       -0.010188
# BedroomAbvGr                                 0.041777
# BsmtCond                                    -0.070625
# BsmtExposure                                 0.056645
# BsmtFinSF1                                  -0.057231
# BsmtFinSF2                                   0.044840
# BsmtFinType1                                 0.039937
# BsmtFinType2                                -0.034741
# BsmtFullBath                                -0.050302
# BsmtHalfBath                                 0.023370
# BsmtQual                                     0.095550
# BsmtUnfSF                                   -0.044620
# CentralAir                                  -0.144875
# EnclosedPorch                                0.071475
# ExterCond                                   -0.036778
# ExterQual                                    0.073941
# Fence                                       -0.035550
# FireplaceQu                                  0.011121
# Fireplaces                                  -0.058369
# FullBath                                    -0.062796
# Functional                                  -0.098738
# GarageArea                                  -0.057843
# GarageCars                                  -0.087032
# GarageCond                                  -0.077897
# GarageFinish                                 0.083825
# GarageQual                                  -0.007072
# GarageYrBlt                                 -0.034592
# ...                                               ...
# SaleType_OverallCond_Con6                   -0.004780
# SaleType_OverallCond_ConLD1                 -0.003379
# SaleType_OverallCond_ConLD2                 -0.003379
# SaleType_OverallCond_ConLD3                 -0.004780
# SaleType_OverallCond_ConLD4                 -0.006762
# SaleType_OverallCond_ConLD5                 -0.011728
# SaleType_OverallCond_ConLD6                 -0.004780
# SaleType_OverallCond_ConLD7                 -0.005855
# SaleType_OverallCond_ConLD8                 -0.003379
# SaleType_OverallCond_ConLI5                 -0.008284
# SaleType_OverallCond_ConLI6                 -0.004780
# SaleType_OverallCond_ConLI8                 -0.003379
# SaleType_OverallCond_ConLw3                 -0.003379
# SaleType_OverallCond_ConLw5                 -0.005855
# SaleType_OverallCond_ConLw6                 -0.006762
# SaleType_OverallCond_New2                   -0.003379
# SaleType_OverallCond_New5                   -0.053387
# SaleType_OverallCond_New6                   -0.008284
# SaleType_OverallCond_Oth3                   -0.003379
# SaleType_OverallCond_Oth5                   -0.005855
# SaleType_OverallCond_Oth6                   -0.005855
# SaleType_OverallCond_WD1                    -0.007561
# SaleType_OverallCond_WD2                    -0.009569
# SaleType_OverallCond_WD3                    -0.021516
# SaleType_OverallCond_WD4                     1.000000
# SaleType_OverallCond_WD5                    -0.167396
# SaleType_OverallCond_WD6                    -0.081791
# SaleType_OverallCond_WD7                    -0.070301
# SaleType_OverallCond_WD8                    -0.041125
# SaleType_OverallCond_WD9                    -0.021516
#
#                              SaleType_OverallCond_WD5  \
# 1stFlrSF                                     0.107150
# 2ndFlrSF                                     0.038264
# 3SsnPorch                                   -0.038146
# Alley                                        0.112284
# BedroomAbvGr                                 0.012149
# BsmtCond                                     0.092783
# BsmtExposure                                -0.102480
# BsmtFinSF1                                   0.072683
# BsmtFinSF2                                  -0.048325
# BsmtFinType1                                 0.016804
# BsmtFinType2                                 0.034275
# BsmtFullBath                                 0.096328
# BsmtHalfBath                                -0.067845
# BsmtQual                                    -0.241797
# BsmtUnfSF                                    0.020545
# CentralAir                                   0.089523
# EnclosedPorch                               -0.154743
# ExterCond                                    0.206169
# ExterQual                                   -0.121183
# Fence                                        0.113778
# FireplaceQu                                  0.076906
# Fireplaces                                   0.092250
# FullBath                                     0.263434
# Functional                                   0.054569
# GarageArea                                   0.137632
# GarageCars                                   0.226655
# GarageCond                                   0.103454
# GarageFinish                                -0.186370
# GarageQual                                   0.114515
# GarageYrBlt                                  0.075849
# ...                                               ...
# SaleType_OverallCond_Con6                   -0.024029
# SaleType_OverallCond_ConLD1                 -0.016988
# SaleType_OverallCond_ConLD2                 -0.016988
# SaleType_OverallCond_ConLD3                 -0.024029
# SaleType_OverallCond_ConLD4                 -0.033994
# SaleType_OverallCond_ConLD5                 -0.058960
# SaleType_OverallCond_ConLD6                 -0.024029
# SaleType_OverallCond_ConLD7                 -0.029434
# SaleType_OverallCond_ConLD8                 -0.016988
# SaleType_OverallCond_ConLI5                 -0.041648
# SaleType_OverallCond_ConLI6                 -0.024029
# SaleType_OverallCond_ConLI8                 -0.016988
# SaleType_OverallCond_ConLw3                 -0.016988
# SaleType_OverallCond_ConLw5                 -0.029434
# SaleType_OverallCond_ConLw6                 -0.033994
# SaleType_OverallCond_New2                   -0.016988
# SaleType_OverallCond_New5                   -0.268391
# SaleType_OverallCond_New6                   -0.041648
# SaleType_OverallCond_Oth3                   -0.016988
# SaleType_OverallCond_Oth5                   -0.029434
# SaleType_OverallCond_Oth6                   -0.029434
# SaleType_OverallCond_WD1                    -0.038013
# SaleType_OverallCond_WD2                    -0.048107
# SaleType_OverallCond_WD3                    -0.108168
# SaleType_OverallCond_WD4                    -0.167396
# SaleType_OverallCond_WD5                     1.000000
# SaleType_OverallCond_WD6                    -0.411182
# SaleType_OverallCond_WD7                    -0.353420
# SaleType_OverallCond_WD8                    -0.206746
# SaleType_OverallCond_WD9                    -0.108168
#
#                              SaleType_OverallCond_WD6  \
# 1stFlrSF                                    -0.077956
# 2ndFlrSF                                    -0.051462
# 3SsnPorch                                   -0.019274
# Alley                                       -0.017840
# BedroomAbvGr                                -0.001010
# BsmtCond                                     0.025735
# BsmtExposure                                 0.044347
# BsmtFinSF1                                   0.078021
# BsmtFinSF2                                   0.060342
# BsmtFinType1                                -0.082966
# BsmtFinType2                                -0.040569
# BsmtFullBath                                -0.007074
# BsmtHalfBath                                 0.035286
# BsmtQual                                     0.234895
# BsmtUnfSF                                   -0.083098
# CentralAir                                  -0.022784
# EnclosedPorch                                0.054130
# ExterCond                                    0.000600
# ExterQual                                    0.207420
# Fence                                       -0.098585
# FireplaceQu                                  0.022396
# Fireplaces                                  -0.000306
# FullBath                                    -0.191748
# Functional                                  -0.014865
# GarageArea                                  -0.057003
# GarageCars                                  -0.133309
# GarageCond                                   0.001422
# GarageFinish                                 0.121619
# GarageQual                                  -0.042721
# GarageYrBlt                                 -0.004241
# ...                                               ...
# SaleType_OverallCond_Con6                   -0.011741
# SaleType_OverallCond_ConLD1                 -0.008300
# SaleType_OverallCond_ConLD2                 -0.008300
# SaleType_OverallCond_ConLD3                 -0.011741
# SaleType_OverallCond_ConLD4                 -0.016609
# SaleType_OverallCond_ConLD5                 -0.028808
# SaleType_OverallCond_ConLD6                 -0.011741
# SaleType_OverallCond_ConLD7                 -0.014382
# SaleType_OverallCond_ConLD8                 -0.008300
# SaleType_OverallCond_ConLI5                 -0.020349
# SaleType_OverallCond_ConLI6                 -0.011741
# SaleType_OverallCond_ConLI8                 -0.008300
# SaleType_OverallCond_ConLw3                 -0.008300
# SaleType_OverallCond_ConLw5                 -0.014382
# SaleType_OverallCond_ConLw6                 -0.016609
# SaleType_OverallCond_New2                   -0.008300
# SaleType_OverallCond_New5                   -0.131137
# SaleType_OverallCond_New6                   -0.020349
# SaleType_OverallCond_Oth3                   -0.008300
# SaleType_OverallCond_Oth5                   -0.014382
# SaleType_OverallCond_Oth6                   -0.014382
# SaleType_OverallCond_WD1                    -0.018573
# SaleType_OverallCond_WD2                    -0.023505
# SaleType_OverallCond_WD3                    -0.052851
# SaleType_OverallCond_WD4                    -0.081791
# SaleType_OverallCond_WD5                    -0.411182
# SaleType_OverallCond_WD6                     1.000000
# SaleType_OverallCond_WD7                    -0.172683
# SaleType_OverallCond_WD8                    -0.101017
# SaleType_OverallCond_WD9                    -0.052851
#
#                              SaleType_OverallCond_WD7  \
# 1stFlrSF                                    -0.121123
# 2ndFlrSF                                     0.011812
# 3SsnPorch                                    0.040701
# Alley                                       -0.053276
# BedroomAbvGr                                 0.001018
# BsmtCond                                    -0.019544
# BsmtExposure                                 0.086120
# BsmtFinSF1                                  -0.005147
# BsmtFinSF2                                   0.050409
# BsmtFinType1                                -0.085273
# BsmtFinType2                                -0.038532
# BsmtFullBath                                -0.035017
# BsmtHalfBath                                 0.025562
# BsmtQual                                     0.189237
# BsmtUnfSF                                   -0.038260
# CentralAir                                   0.013599
# EnclosedPorch                                0.099094
# ExterCond                                   -0.091651
# ExterQual                                    0.152997
# Fence                                       -0.091922
# FireplaceQu                                  0.019935
# Fireplaces                                  -0.065349
# FullBath                                    -0.197986
# Functional                                   0.011015
# GarageArea                                  -0.088089
# GarageCars                                  -0.152179
# GarageCond                                  -0.040515
# GarageFinish                                 0.138722
# GarageQual                                  -0.063701
# GarageYrBlt                                 -0.031911
# ...                                               ...
# SaleType_OverallCond_Con6                   -0.010091
# SaleType_OverallCond_ConLD1                 -0.007134
# SaleType_OverallCond_ConLD2                 -0.007134
# SaleType_OverallCond_ConLD3                 -0.010091
# SaleType_OverallCond_ConLD4                 -0.014276
# SaleType_OverallCond_ConLD5                 -0.024761
# SaleType_OverallCond_ConLD6                 -0.010091
# SaleType_OverallCond_ConLD7                 -0.012361
# SaleType_OverallCond_ConLD8                 -0.007134
# SaleType_OverallCond_ConLI5                 -0.017491
# SaleType_OverallCond_ConLI6                 -0.010091
# SaleType_OverallCond_ConLI8                 -0.007134
# SaleType_OverallCond_ConLw3                 -0.007134
# SaleType_OverallCond_ConLw5                 -0.012361
# SaleType_OverallCond_ConLw6                 -0.014276
# SaleType_OverallCond_New2                   -0.007134
# SaleType_OverallCond_New5                   -0.112716
# SaleType_OverallCond_New6                   -0.017491
# SaleType_OverallCond_Oth3                   -0.007134
# SaleType_OverallCond_Oth5                   -0.012361
# SaleType_OverallCond_Oth6                   -0.012361
# SaleType_OverallCond_WD1                    -0.015964
# SaleType_OverallCond_WD2                    -0.020204
# SaleType_OverallCond_WD3                    -0.045427
# SaleType_OverallCond_WD4                    -0.070301
# SaleType_OverallCond_WD5                    -0.353420
# SaleType_OverallCond_WD6                    -0.172683
# SaleType_OverallCond_WD7                     1.000000
# SaleType_OverallCond_WD8                    -0.086827
# SaleType_OverallCond_WD9                    -0.045427
#
#                              SaleType_OverallCond_WD8  \
# 1stFlrSF                                    -0.099435
# 2ndFlrSF                                     0.043830
# 3SsnPorch                                    0.001736
# Alley                                       -0.119635
# BedroomAbvGr                                -0.004912
# BsmtCond                                    -0.028673
# BsmtExposure                                 0.041681
# BsmtFinSF1                                  -0.038534
# BsmtFinSF2                                   0.014734
# BsmtFinType1                                -0.003483
# BsmtFinType2                                -0.023466
# BsmtFullBath                                -0.029718
# BsmtHalfBath                                 0.048988
# BsmtQual                                     0.103583
# BsmtUnfSF                                   -0.004378
# CentralAir                                   0.022180
# EnclosedPorch                                0.093509
# ExterCond                                   -0.158926
# ExterQual                                    0.062168
# Fence                                       -0.079518
# FireplaceQu                                 -0.015939
# Fireplaces                                  -0.048297
# FullBath                                    -0.096339
# Functional                                  -0.007573
# GarageArea                                  -0.049833
# GarageCars                                  -0.101506
# GarageCond                                  -0.041534
# GarageFinish                                 0.110264
# GarageQual                                  -0.074397
# GarageYrBlt                                 -0.004591
# ...                                               ...
# SaleType_OverallCond_Con6                   -0.005903
# SaleType_OverallCond_ConLD1                 -0.004174
# SaleType_OverallCond_ConLD2                 -0.004174
# SaleType_OverallCond_ConLD3                 -0.005903
# SaleType_OverallCond_ConLD4                 -0.008351
# SaleType_OverallCond_ConLD5                 -0.014485
# SaleType_OverallCond_ConLD6                 -0.005903
# SaleType_OverallCond_ConLD7                 -0.007231
# SaleType_OverallCond_ConLD8                 -0.004174
# SaleType_OverallCond_ConLI5                 -0.010232
# SaleType_OverallCond_ConLI6                 -0.005903
# SaleType_OverallCond_ConLI8                 -0.004174
# SaleType_OverallCond_ConLw3                 -0.004174
# SaleType_OverallCond_ConLw5                 -0.007231
# SaleType_OverallCond_ConLw6                 -0.008351
# SaleType_OverallCond_New2                   -0.004174
# SaleType_OverallCond_New5                   -0.065937
# SaleType_OverallCond_New6                   -0.010232
# SaleType_OverallCond_Oth3                   -0.004174
# SaleType_OverallCond_Oth5                   -0.007231
# SaleType_OverallCond_Oth6                   -0.007231
# SaleType_OverallCond_WD1                    -0.009339
# SaleType_OverallCond_WD2                    -0.011819
# SaleType_OverallCond_WD3                    -0.026574
# SaleType_OverallCond_WD4                    -0.041125
# SaleType_OverallCond_WD5                    -0.206746
# SaleType_OverallCond_WD6                    -0.101017
# SaleType_OverallCond_WD7                    -0.086827
# SaleType_OverallCond_WD8                     1.000000
# SaleType_OverallCond_WD9                    -0.026574
#
#                              SaleType_OverallCond_WD9
# 1stFlrSF                                    -0.028926
# 2ndFlrSF                                     0.062818
# 3SsnPorch                                    0.060905
# Alley                                       -0.070238
# BedroomAbvGr                                 0.013966
# BsmtCond                                    -0.028109
# BsmtExposure                                 0.030971
# BsmtFinSF1                                  -0.021386
# BsmtFinSF2                                   0.006785
# BsmtFinType1                                -0.001281
# BsmtFinType2                                -0.025813
# BsmtFullBath                                -0.034439
# BsmtHalfBath                                 0.055603
# BsmtQual                                     0.044232
# BsmtUnfSF                                   -0.007698
# CentralAir                                   0.008097
# EnclosedPorch                                0.015331
# ExterCond                                   -0.269753
# ExterQual                                   -0.073165
# Fence                                       -0.038825
# FireplaceQu                                 -0.025021
# Fireplaces                                   0.010766
# FullBath                                    -0.002368
# Functional                                   0.016748
# GarageArea                                  -0.048147
# GarageCars                                  -0.045542
# GarageCond                                  -0.006475
# GarageFinish                                 0.017794
# GarageQual                                  -0.034930
# GarageYrBlt                                 -0.050168
# ...                                               ...
# SaleType_OverallCond_Con6                   -0.003089
# SaleType_OverallCond_ConLD1                 -0.002184
# SaleType_OverallCond_ConLD2                 -0.002184
# SaleType_OverallCond_ConLD3                 -0.003089
# SaleType_OverallCond_ConLD4                 -0.004369
# SaleType_OverallCond_ConLD5                 -0.007578
# SaleType_OverallCond_ConLD6                 -0.003089
# SaleType_OverallCond_ConLD7                 -0.003783
# SaleType_OverallCond_ConLD8                 -0.002184
# SaleType_OverallCond_ConLI5                 -0.005353
# SaleType_OverallCond_ConLI6                 -0.003089
# SaleType_OverallCond_ConLI8                 -0.002184
# SaleType_OverallCond_ConLw3                 -0.002184
# SaleType_OverallCond_ConLw5                 -0.003783
# SaleType_OverallCond_ConLw6                 -0.004369
# SaleType_OverallCond_New2                   -0.002184
# SaleType_OverallCond_New5                   -0.034498
# SaleType_OverallCond_New6                   -0.005353
# SaleType_OverallCond_Oth3                   -0.002184
# SaleType_OverallCond_Oth5                   -0.003783
# SaleType_OverallCond_Oth6                   -0.003783
# SaleType_OverallCond_WD1                    -0.004886
# SaleType_OverallCond_WD2                    -0.006183
# SaleType_OverallCond_WD3                    -0.013903
# SaleType_OverallCond_WD4                    -0.021516
# SaleType_OverallCond_WD5                    -0.108168
# SaleType_OverallCond_WD6                    -0.052851
# SaleType_OverallCond_WD7                    -0.045427
# SaleType_OverallCond_WD8                    -0.026574
# SaleType_OverallCond_WD9                     1.000000
#
# [438 rows x 438 columns]

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# transforming year and month into categorical features

# %%
data['YrSold'] = data['YrSold'].astype(str)
data['MoSold'] = data['MoSold'].astype(str)

# %% [markdown]
# gonna try putting overall condition as categorical

# %%
data['OverallCond'] = data['OverallCond'].astype(str)

# %% [markdown]
# MSSubClass should be categorical as well

# %%
data['MSSubClass'] = data['MSSubClass'].astype(str)

# %% [markdown]
# overall SF? we have TotalBsmtSF, 1stFlrSF and 2ndFlrSF
# might be worth putting them together into a "overall SF"category?

# %%
data['OverallSF'] = data['1stFlrSF'] + data['2ndFlrSF'] + data['TotalBsmtSF']

# %% [markdown]
# going to try combining categorical data with it's quality:
# BsmtQual * BsmtCond
# OverallQual * Neighborhood
# Condition1 * Condition2
# BldgType * OverallQual
# ExterQual * ExterCond
# KitchenQual * OverallQual
# GarageType * GarageQual
# GarageType * GarageCond
# MoSold * YrSold
# SaleType * SaleCondition
# SaleType * OverallCond

# %% [markdown]
# Lasso score: 0.1122 (0.0134)
# ElasticNet score: 0.1098 (0.0145)

# %%
data['BsmnQual_BsmtCond'] = data['BsmtQual'] + data['BsmtCond']
#data['OverallQual_Neighborhood'] = data['OverallQual'] + data['Neighborhood']
data['Condition1_Condition2'] = data['Condition1'] + data['Condition2']
#data['BldgType_OverallQual'] = data['BldgType'] + data['OverallQual']
data['ExterQual_ExterCond'] = data['ExterQual'] + data['ExterCond']
#data['KitchenQual_OverallQual'] = data['KitchenQual'] + data['OverallQual']
data['GarageType_GarageQual'] = data['GarageType'] + data['GarageQual']
#data['GarageType_GarageCond'] = data['GarageType'] + data['GarageCond']
data['MoSold_YrSold'] = data['MoSold'] + data['YrSold']
data['SaleType_SaleCondition'] = data['SaleType'] + data['SaleCondition']
data['SaleType_OverallCond'] = data['SaleType'] + data['OverallCond']

# %%
# Out:
# 1stFlrSF               int64
# 2ndFlrSF               int64
# 3SsnPorch              int64
# Alley                 object
# BedroomAbvGr           int64
# BldgType              object
# BsmtCond              object
# BsmtExposure          object
# BsmtFinSF1           float64
# BsmtFinSF2           float64
# BsmtFinType1          object
# BsmtFinType2          object
# BsmtFullBath         float64
# BsmtHalfBath         float64
# BsmtQual              object
# BsmtUnfSF            float64
# CentralAir            object
# Condition1            object
# Condition2            object
# Electrical            object
# EnclosedPorch          int64
# ExterCond             object
# ExterQual             object
# Exterior1st           object
# Exterior2nd           object
# Fence                 object
# FireplaceQu           object
# Fireplaces             int64
# Foundation            object
# FullBath               int64
#                       ...
# LotShape              object
# LowQualFinSF           int64
# MSSubClass            object
# MSZoning              object
# MasVnrArea           float64
# MasVnrType            object
# MiscFeature           object
# MiscVal                int64
# MoSold                object
# Neighborhood          object
# OpenPorchSF            int64
# OverallCond           object
# OverallQual            int64
# PavedDrive            object
# PoolArea               int64
# PoolQC                object
# RoofMatl              object
# RoofStyle             object
# SaleCondition         object
# SaleType              object
# ScreenPorch            int64
# Street                object
# TotRmsAbvGrd           int64
# TotalBsmtSF          float64
# WoodDeckSF             int64
# YearBuilt              int64
# YearRemodAdd           int64
# YrSold                object
# OverallSF            float64
# BsmnQual_BsmtCond     object
# Length: 80, dtype: object

# %% [markdown]
# # Figuring out what to do with Nominal & Ordinal Categories

# %% [markdown]
# According to the Data Documentation this is the breakdown on the Nominal and Ordinal Categories- 1st attempt I just used .get_dummies() on everything, but that gave:
# Lasso score: 0.2779 (0.0385), which is, well, terrible so going to try and convert the ordinal categories.
# Right, so after this change i got Lasso score: 0.2790 (0.0380), which has lower standard deviation, but higher mean score. well crappers. running the changes to ordinal categories before adjusting for skew i got Lasso score: 0.2811 (0.0381) so that's worse again. hahahahaha. *cries*. not running the skew adjustment for any of the independent variables i got Lasso score: 0.2850 (0.0407). removing utilities gave me Lasso score: 0.2805 (0.0374). with adding some more nominals to the Label encoder i got Lasso score: 0.2900 (0.0219), which is less standard deviation which might be good?

# %% [markdown]
# Nomial categories

# %% [markdown]
# "MSSubClass", MSZoning, "Street", "Alley", LandContour, LotConfig, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, RoofStyle, RoofMatl, Exterior1, Exterior2, MasVnrType, MasVnrArea, Foundation, Heating, "CentralAir", GarageType, MiscFeature, SaleType, SaleCondition

# %% [markdown]
# Ordinal Categories

# %% [markdown]
# LotShape, Utilities, LandSlope, OverallQual, OverallCond, ExterQual, ExterCond, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2, HeatingQC, Electrical, KitchenQual, Functional, FireplaceQu, GarageFinish, GarageQual, GarageCond, PavedDrive, PoolQC, Fence

# %% [markdown]
# this time i'm going to try converting the ordinal categories with label encoding. It looks like it basically factorizes the values

# %% [markdown]
# one hot encoding for linear models
# label encoder for trees

# %% [markdown]
# Categorical Features with many categories -  rows:category ratio 20:1 or less
# use label count encoding

# %% [markdown]
# class LabelCountEncoder(object):
#     def __init__(self):
#         self.count_dict ={}
#
#     def fit(self, column):
#         count = column.value_counts().to_dict()
#         self.count_dict = {key[0]: rank+1 for rank, key in enumerate(sorted(count.items(), key=lambda x:x[1]))}
#
#     def trasnform(self,column):
#         missing = 0
#         return column.apply(lambda x: self.count_dict.get(x, missing))
#     def fit_transform(self, column):
#         self.fit(column)
#         return self.trasnform(column)

# %%
from sklearn.preprocessing import LabelEncoder
category = ('LotShape', 'LandSlope', 'OverallCond', 'ExterQual', 'ExterCond', 
            'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
            'HeatingQC', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageFinish',
            'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'OverallCond', 
            'YrSold', 'MoSold', 'Street', 'Alley', 'CentralAir', 'MSSubClass')

for c in category:
    lbl = LabelEncoder()
    lbl.fit(list(data[c].values))
    data[c] = lbl.transform(list(data[c].values))

# %%
data.groupby("LotShape").count()
# Out:
#           1stFlrSF  2ndFlrSF  3SsnPorch  Alley  BedroomAbvGr  BldgType  \
# LotShape
# 0              967       967        967    967           967       967
# 1               76        76         76     76            76        76
# 2               15        15         15     15            15        15
# 3             1859      1859       1859   1859          1859      1859
#
#           BsmtCond  BsmtExposure  BsmtFinSF1  BsmtFinSF2    ...      SaleType  \
# LotShape                                                    ...
# 0              967           967         967         967    ...           967
# 1               76            76          76          76    ...            76
# 2               15            15          15          15    ...            15
# 3             1859          1859        1859        1859    ...          1859
#
#           ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  \
# LotShape
# 0                 967     967           967          967         967
# 1                  76      76            76           76          76
# 2                  15      15            15           15          15
# 3                1859    1859          1859         1859        1859
#
#           YearBuilt  YearRemodAdd  YrSold  OverallSF
# LotShape
# 0               967           967     967        967
# 1                76            76      76         76
# 2                15            15      15         15
# 3              1859          1859    1859       1859
#
# [4 rows x 78 columns]

# %% [markdown]
# gonna try rerunning the boxcox with these Label Encoded Values

# %% [markdown]
# # Skewness

# %%
numerical = data.dtypes[data.dtypes != "object"].index

# %%
skewed = data[numerical].apply(lambda x: x.skew()).sort_values()

# %%
skewed
# Out:
# PoolQC          -21.228518
# Street          -15.502729
# Functional       -4.056212
# GarageYrBlt      -3.906642
# GarageCond       -3.596139
# CentralAir       -3.459334
# GarageQual       -3.074369
# BsmtFinType2     -3.044545
# PavedDrive       -2.979273
# BsmtCond         -2.862744
# ExterCond        -2.497774
# Fence            -1.993675
# ExterQual        -1.800989
# KitchenQual      -1.450560
# BsmtExposure     -1.117896
# Alley            -0.652041
# MoSold           -0.646506
# LotShape         -0.618882
# GarageFinish     -0.610267
# YearBuilt        -0.599503
# BsmtQual         -0.488614
# YearRemodAdd     -0.450365
# GarageCars       -0.219410
# BsmtFinType1      0.083684
# YrSold            0.132064
# MSSubClass        0.139781
# FullBath          0.165599
# OverallQual       0.189688
# GarageArea        0.216968
# BedroomAbvGr      0.326736
# FireplaceQu       0.332782
# HeatingQC         0.485784
# OverallCond       0.569607
# BsmtFullBath      0.622735
# TotalBsmtSF       0.672097
# HalfBath          0.697024
# Fireplaces        0.725651
# TotRmsAbvGrd      0.749618
# 2ndFlrSF          0.861999
# BsmtUnfSF         0.920161
# BsmtFinSF1        0.981149
# OverallSF         1.009676
# GrLivArea         1.069300
# LotFrontage       1.103606
# 1stFlrSF          1.257933
# WoodDeckSF        1.845741
# OpenPorchSF       2.530660
# MasVnrArea        2.623068
# BsmtHalfBath      3.932018
# ScreenPorch       3.947131
# EnclosedPorch     4.004404
# BsmtFinSF2        4.146636
# KitchenAbvGr      4.302763
# LandSlope         4.975813
# 3SsnPorch        11.377932
# LowQualFinSF     12.090757
# LotArea          13.116240
# PoolArea         17.697766
# MiscVal          21.950962
# dtype: float64

# %% [markdown]
# allright, a lot of these are incredibly skewed- talking with YuHan it sounded like we'd be good to use boxcox on these

# %%
skewdf = pd.DataFrame({'Skew': skewed})
skewdf.head(3)
# Out:
#                  Skew
# PoolQC     -21.228518
# Street     -15.502729
# Functional  -4.056212

# %%
skewdf = skewdf[abs(skewdf)>0.75]
from scipy.special import boxcox1p
skewed = skewdf.index
lam = 0.15
for feat in skewed:
    data[feat] = boxcox1p(data[feat], lam)

# %%
newskewed = data[numerical].apply(lambda x: x.skew()).sort_values()

# %%
newskewed
# Out:
# PoolQC          -22.835591
# Street          -15.502729
# Functional       -5.127355
# GarageCond       -4.176566
# TotalBsmtSF      -3.987517
# GarageYrBlt      -3.925767
# BsmtFinType2     -3.772005
# CentralAir       -3.459334
# GarageQual       -3.442342
# BsmtCond         -3.229921
# PavedDrive       -3.065684
# GarageArea       -3.046366
# ExterCond        -3.015035
# ExterQual        -2.855404
# Alley            -2.628308
# Fence            -2.538703
# KitchenQual      -2.207198
# BsmtUnfSF        -1.538077
# MoSold           -1.486383
# BsmtExposure     -1.408804
# MSSubClass       -1.292497
# BsmtQual         -1.267743
# GarageCars       -1.106936
# OverallCond      -0.929905
# GarageFinish     -0.856086
# FireplaceQu      -0.806556
# LotFrontage      -0.799316
# BedroomAbvGr     -0.753856
# LotShape         -0.646599
# YearBuilt        -0.621941
# BsmtFinType1     -0.490562
# OverallQual      -0.489180
# BsmtFinSF1       -0.489117
# YearRemodAdd     -0.456434
# YrSold           -0.400841
# OverallSF        -0.208110
# FullBath         -0.180186
# OpenPorchSF       0.099432
# GrLivArea         0.130118
# TotRmsAbvGrd      0.135559
# LotArea           0.177826
# 1stFlrSF          0.179210
# WoodDeckSF        0.224297
# Fireplaces        0.285457
# HeatingQC         0.286591
# 2ndFlrSF          0.329048
# BsmtFullBath      0.442015
# HalfBath          0.592853
# MasVnrArea        0.637716
# EnclosedPorch     2.025363
# BsmtFinSF2        2.564554
# ScreenPorch       2.978584
# KitchenAbvGr      3.699206
# BsmtHalfBath      3.788634
# LandSlope         4.532595
# MiscVal           5.597842
# LowQualFinSF      8.745528
# 3SsnPorch         8.926241
# PoolArea         15.767638
# dtype: float64

# %%
data = pd.get_dummies(data)

# %%
data.shape
# Out:
# (2917, 438)

# %% [markdown]
# Re-separating the data into test and train

# %%
train = data[:ntrain]
test = data[ntrain:]

# %% [markdown]
# # Running the Models

# %%
# Load libraries
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor as rfr,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error

# %%
n_folds = 10
#this looks better, lets me use kfolds
def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=1).get_n_splits(train.values)
    rmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

#def rmse(predictions, targets):
#    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.00099, random_state=1))

# %%
lasso
# Out:
# Pipeline(memory=None,
#      steps=[('robustscaler', RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True)), ('lasso', Lasso(alpha=0.00099, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False))])

# %%
score = rmsle_cv(lasso)
print("Lasso score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# Lasso score: 0.1122 (0.0134)

# %% [markdown]
# switched away from boxcox to log1p and instantly improved by over 10%

# %%
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=1))

# %%
score = rmsle_cv(ENet)
print("ElasticNet score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# ElasticNet score: 0.1098 (0.0145)

# %% [markdown]
# ok so my scores are terrible, i'm probably going to need to go back and mess with the data classifications

# %%
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)

# %%
score = rmsle_cv(GBoost)
print("Gradient Boosting score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Gradient Boosting score: 0.1135 (0.0154)

# %%
LGBoost = GradientBoostingRegressor(n_estimators=1000, learning_rate=0.05,
                                   max_depth=2, max_features='sqrt',
                                    min_samples_leaf=15, min_samples_split=10,
                                    loss='huber', random_state =5)

# %%
score = rmsle_cv(LGBoost)
print("LGBM score: {:.4f} ({:.4f})\n" .format(score.mean(), score.std()))
# Out:
# LGBM score: 0.1137 (0.0146)

# %%
rfr = rfr(random_state=0,
        n_estimators=1000, max_depth=6,  max_features='sqrt')

# %%
score = rmsle_cv(rfr)
print("rfr score: {:.4f} ({:.4f})\n" .format(score.mean(), score.std()))
# Out:
# rfr score: 0.1676 (0.0154)

# %%
rfr = rfr(random_state=0, 
        n_estimators=1000, max_depth=9, max_features = 'auto')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1334-0aef4495dede> in <module>()
#       1 rfr = rfr(random_state=0,
# ----> 2         n_estimators=1000, max_depth=9, max_features = 'auto')
#
# TypeError: 'RandomForestRegressor' object is not callable

# %%
score = rmsle_cv(Agressiverfr)
print("Aggr rfr score: {:.4f} ({:.4f})".format(score.mean(), score.std()))

# %%
lasso.fit(train.values, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('robustscaler', RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True)), ('lasso', Lasso(alpha=0.00099, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False))])

# %%
final = lasso.predict(test)

# %%
final
# Out:
# array([ 11.67981144,  11.92951767,  12.128261  , ...,  12.08454216,
#         11.68065902,  12.34616607])

# %%
results = np.expm1(lasso.predict(test))

# %%
results
# Out:
# array([ 118160.9524735 ,  151677.38491008,  185026.73348107, ...,
#         177111.81059211,  118261.14615152,  230075.25463554])

# %%
attempt2 = pd.DataFrame()
attempt1['Id'] = test_ID
attempt1['SalePrice'] = results
attempt1.to_csv('submit2.csv', index=False)

# %% [markdown]
# # Ensembling

# %% [markdown]
# try and grab 2 random forest, 1 or 2 regression and 2 or 3 gbr
